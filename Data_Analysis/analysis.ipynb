# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("./dataset/data.csv")

# %%
df
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean
# 0      842302         M        17.99         10.38          122.80     1001.0  \
# 1      842517         M        20.57         17.77          132.90     1326.0
# 2    84300903         M        19.69         21.25          130.00     1203.0
# 3    84348301         M        11.42         20.38           77.58      386.1
# 4    84358402         M        20.29         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 564    926424         M        21.56         22.39          142.00     1479.0
# 565    926682         M        20.13         28.25          131.20     1261.0
# 566    926954         M        16.60         28.08          108.30      858.1
# 567    927241         M        20.60         29.33          140.10     1265.0
# 568     92751         B         7.76         24.54           47.92      181.0
#
# ...

# %%
#pre-processing look for nans
df.isna().sum().sum()

#Shows that there are 569 nan values that need to be filled up or dropped
# Out:
# 569

# %%
#removing columns with only NaN values
df=df.dropna(axis=1)

# %%
df.isna().sum().sum()
# Out:
# 0

# %%
#The Un-named column with all nans have been dropped. There are no more null values
df
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean
# 0      842302         M        17.99         10.38          122.80     1001.0  \
# 1      842517         M        20.57         17.77          132.90     1326.0
# 2    84300903         M        19.69         21.25          130.00     1203.0
# 3    84348301         M        11.42         20.38           77.58      386.1
# 4    84358402         M        20.29         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 564    926424         M        21.56         22.39          142.00     1479.0
# 565    926682         M        20.13         28.25          131.20     1261.0
# 566    926954         M        16.60         28.08          108.30      858.1
# 567    927241         M        20.60         29.33          140.10     1265.0
# 568     92751         B         7.76         24.54           47.92      181.0
#
# ...

# %%
#mapping categorical variables to numeric features
mapping={'M':1,'B':0}

df=df.replace(mapping)

# %%
df
# Out:
#            id  diagnosis  radius_mean  texture_mean  perimeter_mean
# 0      842302          1        17.99         10.38          122.80  \
# 1      842517          1        20.57         17.77          132.90
# 2    84300903          1        19.69         21.25          130.00
# 3    84348301          1        11.42         20.38           77.58
# 4    84358402          1        20.29         14.34          135.10
# ..        ...        ...          ...           ...             ...
# 564    926424          1        21.56         22.39          142.00
# 565    926682          1        20.13         28.25          131.20
# 566    926954          1        16.60         28.08          108.30
# 567    927241          1        20.60         29.33          140.10
# 568     92751          0         7.76         24.54           47.92
#
#      area_mean  smoothness_mean  compactness_mean  concavity_mean
# 0       1001.0          0.11840           0.27760         0.30010  \
# ...

# %%
import matplotlib.pyplot as plt

# %%
#plotting correlation matrix for dimensionality reduction
plt.matshow(df.corr())

# %%
df.corr()
# Out:
#                                id  diagnosis  radius_mean  texture_mean
# id                       1.000000   0.039769     0.074626      0.099770  \
# diagnosis                0.039769   1.000000     0.730029      0.415185
# radius_mean              0.074626   0.730029     1.000000      0.323782
# texture_mean             0.099770   0.415185     0.323782      1.000000
# perimeter_mean           0.073159   0.742636     0.997855      0.329533
# area_mean                0.096893   0.708984     0.987357      0.321086
# smoothness_mean         -0.012968   0.358560     0.170581     -0.023389
# compactness_mean         0.000096   0.596534     0.506124      0.236702
# concavity_mean           0.050080   0.696360     0.676764      0.302418
# concave points_mean      0.044158   0.776614     0.822529      0.293464
# symmetry_mean           -0.022114   0.330499     0.147741      0.071401
# fractal_dimension_mean  -0.052511  -0.012838    -0.311631     -0.076437
# ...

# %%
#From the correlation matrix, features with less than 0.05 dependency can be dropped.
drop_columns=['texture_se','fractal_dimension_mean','smoothness_se','symmetry_se']

df=df.drop(drop_columns,axis=1)

# %%
df
# Out:
#            id  diagnosis  radius_mean  texture_mean  perimeter_mean
# 0      842302          1        17.99         10.38          122.80  \
# 1      842517          1        20.57         17.77          132.90
# 2    84300903          1        19.69         21.25          130.00
# 3    84348301          1        11.42         20.38           77.58
# 4    84358402          1        20.29         14.34          135.10
# ..        ...        ...          ...           ...             ...
# 564    926424          1        21.56         22.39          142.00
# 565    926682          1        20.13         28.25          131.20
# 566    926954          1        16.60         28.08          108.30
# 567    927241          1        20.60         29.33          140.10
# 568     92751          0         7.76         24.54           47.92
#
#      area_mean  smoothness_mean  compactness_mean  concavity_mean
# 0       1001.0          0.11840           0.27760         0.30010  \
# ...

# %%
#Statistical Dataanlysis
df.describe()
# Out:
#                  id   diagnosis  radius_mean  texture_mean  perimeter_mean
# count  5.690000e+02  569.000000   569.000000    569.000000      569.000000  \
# mean   3.037183e+07    0.372583    14.127292     19.289649       91.969033
# std    1.250206e+08    0.483918     3.524049      4.301036       24.298981
# min    8.670000e+03    0.000000     6.981000      9.710000       43.790000
# 25%    8.692180e+05    0.000000    11.700000     16.170000       75.170000
# 50%    9.060240e+05    0.000000    13.370000     18.840000       86.240000
# 75%    8.813129e+06    1.000000    15.780000     21.800000      104.100000
# max    9.113205e+08    1.000000    28.110000     39.280000      188.500000
#
#          area_mean  smoothness_mean  compactness_mean  concavity_mean
# count   569.000000       569.000000        569.000000      569.000000  \
# mean    654.889104         0.096360          0.104341        0.088799
# std     351.914129         0.014064          0.052813        0.079720
# ...

# %%
#Data Visualization
plt.hist(df['diagnosis'])
plt.title("Distribution of Benign and Malignant Tumors")
# Out:
# Text(0.5, 1.0, 'Distribution of Benign and Malignant Tumors')

# %%
#Scatter plot to depict corrleation between area mean and radius_mean
x=df['area_mean']
y=df['radius_mean']

plt.scatter(x,y)
plt.title("Relation between radius mean and area mean")

#the plot shows a strong linear correlation
# Out:
# Text(0.5, 1.0, 'Relation between radius mean and area mean')

# %%
#Normalize around expectation of 0 and distribution standard deviation of 1.
for i in list(df.columns):
    if (i!='id' and i!='diagnosis'):
        df[i]=(df[i]-df[i].mean())/df[i].std()

# %%
df
# Out:
#            id  diagnosis  radius_mean  texture_mean  perimeter_mean
# 0      842302          1     1.096100     -2.071512        1.268817  \
# 1      842517          1     1.828212     -0.353322        1.684473
# 2    84300903          1     1.578499      0.455786        1.565126
# 3    84348301          1    -0.768233      0.253509       -0.592166
# 4    84358402          1     1.748758     -1.150804        1.775011
# ..        ...        ...          ...           ...             ...
# 564    926424          1     2.109139      0.720838        2.058974
# 565    926682          1     1.703356      2.083301        1.614511
# 566    926954          1     0.701667      2.043775        0.672084
# 567    927241          1     1.836725      2.334403        1.980781
# 568     92751          0    -1.806811      1.220718       -1.812793
#
#      area_mean  smoothness_mean  compactness_mean  concavity_mean
# 0     0.983510         1.567087          3.280628        2.650542  \
# ...
